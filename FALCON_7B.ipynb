# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheiphan/All-LLMs-Projects/blob/main/FALCON_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 82.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

# Load the libraries 
model = "tiiuae/falcon-7b-instruct"

# Load the Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model)

# %%
# Build the Model Pipeline using Hugging Face Transformers Pipeline
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)

# %%
prompt = "How to make it in the LLM race"

# %%
# Model Inference using the pipeline that was built above
sequences = pipeline(
    prompt,
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.

# %%
# Print the Final Result
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: How to make it in the LLM race - 5 ways to get started
# A lot of people have a misconception that a LLM - or more generally, any higher legal education - is a degree in law, but this is far from the case. The LLM is actually quite broad and can be a great degree to study for many people.
# For those of you out there who are interested in a higher legal education, but don’t see yourself doing a law degree, an LLM could be an option. Here are five ways to get started with a LLM degree.
# 1. Do it for a career in the legal profession
# One of the most popular reasons people pursue LLMs is to improve their performance, or get a promotion, in the legal sector. In fact, many LLMs are designed to provide the skills and knowledge necessary to work as a solicitor and to take a role in a law firm.
# In these instances, an LLM can
